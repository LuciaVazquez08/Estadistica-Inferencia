# %% [markdown]
# regresion lineal con bayes
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ajuste con PYMC - prior no informativo
#
# ![image.png](attachment:image.png)
#
# mu es un modelo lineal, and mi y tiene cierto ruido gaussiano
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# BAYESIANO:
#
# ![image.png](attachment:image.png)
#
# samplear es una forma inteligente de recorer la grilla, petro esto hace mas rapido
#
# ![image-2.png](attachment:image-2.png)
#
# de esto interpreto que segun mis resultados, la distribucion de la posterior es la del grafico resultante. Cuantos mas puntos sampleo, se suavizan las montañitas, pero se ve la definicion mejor. O sea, al armar el modelo, ya hay un modelo, ala gregar mas puntos, simplemete tengo mas herramientas para graficar

# %% [markdown]
# CON PRIORS MAS INFORMATIVOS

# %% [markdown]
# ![image.png](attachment:image.png)
#
# AHORA EL VALOR MEDIO DE LA DISTRIBUCION SE VA A ACERCAR AL DEL PRIOR
#
# con uno medianamente informativo se va acercando hasta el punto de la dist. Lo informativo de un prior normal depende de su sigma

# %% [markdown]
# Si en lugar de 100 og puntos tengo mas, la likelihood es mas finita, xq tiene mas definicion, y le empieza a ganar al prior. O sea, tengo mas seguridad sobre la distribucion de la posterior. Con normal es regularizacion de reich y con pm.Laplaxe es regularizacion de Lasso.

# %% [markdown]
# QUE PASA SI HACEMOS UN MODELO N-DIMENCIONAL

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# SI LAS HAGO VARIABLES CORRELACIONADAS
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# pierde la capacidad de ajuste.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# si hacemos un zoom en algun punto, vemos que estan correlacioandas, pero opuestas

# %% [markdown]
# ![image.png](attachment:image.png)
#
# correlacion entre las trazas
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# la amnera de resolver este problema seria que reparametrizo este modelo, para que no esten relacioandas las variables. O sea, hago la distribucion del modelo y temino con valores nuevos que no tienen relacion
